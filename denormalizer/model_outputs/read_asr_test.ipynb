# %%
ref_file_path = "../eval/eval_data/asr_test/asr_eval_target.txt"

# %%
src_file_path = "../eval/eval_data/asr_test/asr_eval_input.txt"

# %%
hypo_path = "GTNaisg_SPGI/asr_hypothesis.txt"

# %%
with open(src_file_path, "r") as src_file, open(ref_file_path, "r") as ref_file, open(hypo_path, "r") as hypo_file:
    src_lines = src_file.readlines()
    ref_lines = ref_file.readlines()
    hypo_lines = hypo_file.readlines()
    for src_line, ref_line, hypo_line in zip(src_lines, ref_lines, hypo_lines):
        print("SRC:", src_line.strip())
        print("HYP:", hypo_line.strip())
        print("REF:", ref_line.strip())
        print()
# Out:
# SRC: compassvale drive the chevrons and aljunied avenue five
# HYP: Compassvale Drive The Chevrons and Aljunied Avenue 5 .
# REF: compassvale drive the chevrons and aljunied avenue 5
#
# SRC: yishun street forty one appeals board and seletar green avenue
# HYP: Yishun Street 41 appeals board and seletar green avenue .
# REF: yishun street 41 appeals board and seletar green avenue
#
# SRC: are there food courts or restaurants near lorong nine geylang
# HYP: Are there food courts or restaurants near Lorong 9 Geylang .
# REF: are there food courts or restaurants near lorong 9 geylang
#
# SRC: please show me the way to seletar lodge one
# HYP: Please show me the way to seletar lodge 1 .
# REF: please show me the way to seletar lodge 1
#
# SRC: gilstead road bedok north and one north link
# HYP: Gilstead Road bedok north and one north link .
# REF: gilstead road bedok north and one north link
#
# SRC: promenade siang cho keong temple and library at chinatown
# ...
