# %%
model_output = "/home/mazhang/pt/txtDenormalization/denormalizer/test_on_asr_ITN.txt"
asr_input = "/home/mazhang/pt/inverse-text-normailzation/data_and_result/asr_test/asr_eval_input.txt"
asr_target = "/home/mazhang/pt/inverse-text-normailzation/data_and_result/asr_test/asr_eval_target.txt"

# %%
with open(model_output) as f1, open(asr_input) as f2, open(asr_target) as f3:
    for output, input, target in zip(f1, f2, f3):
        print(input.strip())
        print(output.strip())
        print(target.strip())
        print()
# Out:
# compassvale drive the chevrons and aljunied avenue five
# COMPASSVALE DRIVE THE CHEVRONS AND ALJUNIED AVENUE FIVE.
# compassvale drive the chevrons and aljunied avenue 5
#
# yishun street forty one appeals board and seletar green avenue
# YISHUN, STREET, 41. APPEALS BOARD AND SELETAR GREEN AVENUE.
# yishun street 41 appeals board and seletar green avenue
#
# are there food courts or restaurants near lorong nine geylang
# Are there food courts or restaurants near Lorong? 9. GYLANG.
# are there food courts or restaurants near lorong 9 geylang
#
# please show me the way to seletar lodge one
# Please show me the way to Seletar Lodge
# please show me the way to seletar lodge 1
#
# gilstead road bedok north and one north link
# GILSTEAD ROAD BEDOK NORTH AND ONE NORTH LINK.
# gilstead road bedok north and one north link
#
# promenade siang cho keong temple and library at chinatown
# PROMENADE SIANG CHO KEONG TEMPLE AND LIBRARY AT CHINATON.
# ...
