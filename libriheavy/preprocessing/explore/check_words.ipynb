# %%
source_path = "/home/mazhang/pt/libriheavy/cleaned_data/train.raw.source_meduim"
target_path = "/home/mazhang/pt/libriheavy/cleaned_data/train.raw.target_medium"

# %%
with open(source_path, "r") as source, open(target_path, "r") as target:
    for s, t in zip(source, target):
        if s.find("mister brown")!=-1:
            print(s.strip())
            print(t.strip())
            print()
# Out:
# the writers are content to say that mister brown is uncomfortable with missus brown and the last emancipation for separated couples seems only to mean that he is still uncomfortable without missus brown
# The writers are content to say that Mr. Brown is uncomfortable with Mrs. Brown, and the last emancipation, for separated couples, seems only to mean that he is still uncomfortable without Mrs. Brown.
#
# kiss me quick and let me go as the song says i only wish burnet was next door to westedda street next day mister browne sailed away with his handful of roses as elsie sentimentally termed them and indeed rose by herself would have been a handful for almost any man and clover like lord allen was left lamenting
# ...

# %%
target_path = "/home/mazhang/pt/libriheavy/cleaned_data/ITN/train.raw.target_medium"
source_path = "/home/mazhang/pt/libriheavy/cleaned_data/ITN/train.raw.target_medium"
with open(source_path, "r") as source, open(target_path, "r") as target:
    source_lines = source.readlines()
    target_lines = target.readlines()

# %%
import random

# %%
random.shuffle(source_lines)
random.shuffle(target_lines)

# %%
for line in zip(source_lines[:100]:
    print(line.strip())
    print()
# Out:
# "No. 22: a printing office." said Sybil; for the street she had entered was so dark she despaired of finding her way, and ventured to trust so far a guide who was not a policeman. "The very house I am going to," said the stranger: "I am a printer." And they walked on some way, until they at length stopped before a glass and illumined door, covered with a red curtain.
#
# That I may yet often hear the same, wishes your most affectionate aunt, CAR. HERSCHEL.
#
# The verger shows with a pride little short of proprietary a mahogany altar said to have been taken from one of the vessels of the Armada and therefore oddly inappropriate for a Church of England service, and the tomb of one Alan Grebell, who, happening one night in 1742 to be wearing the cloak of his brother in law the Mayor, was killed in mistake for him by a "sanguinary butcher" named Breeds.
#
# ...
